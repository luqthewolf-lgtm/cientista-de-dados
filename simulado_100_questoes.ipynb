# %% [markdown]
# # Simulado Itau Unibanco -- Cientista de Dados 1 e 2
# ## 100 Questoes com Gabarito Comentado
#
# ---
#
# ## Honestidade primeiro -- leia antes de comecar
#
# **Nao existe vazamento oficial da prova atual do Itau.**
# Qualquer material que afirme "questoes vazadas de 2025" esta mentindo.
#
# **O que existe (e que foi usado para construir este simulado):**
#
# 1. **Repositorio oficial do lorduakiti no GitHub:** contem o padrao das questoes 10, 11, 12, 20, 21, 30 da prova de 2019. Essas questoes sao o unico material oficial publico.
#
# 2. **Conteudo programatico oficial da prova:** publicado no mesmo repositorio, cobrindo estatistica, ML, validacao, metricas, clustering.
#
# 3. **Relatos do Glassdoor:** 12+ candidatos descrevendo as entrevistas tecnicas e os topicos mais perguntados.
#
# 4. **Reclame Aqui:** confirmou que a prova atual tem 37 questoes e duracao de 3 horas.
#
# **Estrategia deste simulado:**
# - Nivel de dificuldade PROPOSITALMENTE ACIMA da prova real
# - Se voce gabaritar aqui, passa na prova com folga
# - Coberturas especificas das pegadinhas das Q10-Q11-Q20-Q21-Q30
#
# ---
#
# ## Estrutura do simulado
#
# **100 questoes divididas em:**
#
# | Bloco | N | Peso | Tema |
# |-------|---|------|------|
# | 1     | 20 | Alto | Estatistica (probabilidade, distribuicoes, testes) |
# | 2     | 20 | Alto | Machine Learning Conceitual |
# | 3     | 15 | Muito Alto | Regressao (Linear, Ridge, Lasso, ElasticNet) |
# | 4     | 15 | Muito Alto | Classificacao (Logistica, Arvores, XGBoost) |
# | 5     | 10 | Alto | Validacao e Metricas |
# | 6     | 10 | Medio | Clustering, PCA, Nao-Supervisionado |
# | 7     | 10 | Medio | SQL, Engenharia de Dados, Python |
#
# Total: **100 questoes**
#
# ---
#
# ## Regras para simular a prova real
#
# 1. **Cronometro: 150 minutos para 100 questoes** (1.5 min/questao, dobra o tempo da prova por questao pois o nivel e mais alto)
# 2. **Sistema de penalidade:** cada errada anula uma certa. **Se nao tiver certeza, deixe em branco.** Esse e o truque da prova.
# 3. **Nao volte:** simule a experiencia de so avancar.
# 4. **Use Python ou papel, nao a internet.** A prova real nao permite consulta.
# 5. **Anote suas respostas** em papel ou em uma celula no final.
# 6. **So veja o gabarito no final, UMA VEZ.**
#
# ---
#
# ## Como interpretar sua pontuacao
#
# ```
# Pontuacao = (N_certas - N_erradas)     <- sistema de penalidade
# Questoes em branco nao penalizam
# ```
#
# | Pontuacao | Diagnostico |
# |-----------|-------------|
# | >= 80 | Voce passa na prova com folga. Esta no nivel de senior. |
# | 60-79 | Voce passa na prova. Revise as areas fracas. |
# | 40-59 | Voce pode passar ou nao. Foque nos pontos fracos. |
# | < 40 | Ainda falta base. Volte aos guias 1-3 antes de testar de novo. |

# %% [markdown]
# ---
# ## Bloco 1 -- Estatistica (Q1 a Q20)
#
# **Temas cobrados:** Probabilidade, distribuicoes, testes de hipotese, IC, correlacao, GLM, algebra matricial.
#
# **Padrao de pegadinha:** alternativas onde 3 das 4 opcoes parecem corretas em uma leitura rapida.

# %%
print('='*70)
print('BLOCO 1 -- ESTATISTICA')
print('='*70)
print()
print('Q001) Uma variavel aleatoria X segue distribuicao Normal com media 100 e desvio-padrao 15. Qual a probabilidade aproximada de X estar entre 85 e 115?')
print('   (a) 50%')
print('   (b) 68%')
print('   (c) 95%')
print('   (d) 99.7%')
print()
print('Q002) Considere 50 lancamentos de uma moeda honesta. Qual a distribuicao do numero de caras?')
print('   (a) Poisson(25)')
print('   (b) Normal(25, 12.5)')
print('   (c) Binomial(50, 0.5)')
print('   (d) Uniforme[0,50]')
print()
print('Q003) Um teste bilateral resultou em p-valor = 0.03. A que conclusao chegamos com alpha = 0.05?')
print('   (a) H0 e verdadeira com 97% de probabilidade')
print('   (b) Rejeitamos H0')
print('   (c) H1 e verdadeira com 97% de confianca')
print('   (d) Nao rejeitamos H0')
print()
print('Q004) O poder de um teste estatistico e:')
print('   (a) P(rejeitar H0 | H0 verdadeira)')
print('   (b) P(rejeitar H0 | H1 verdadeira)')
print('   (c) P(nao rejeitar H0 | H0 verdadeira)')
print('   (d) P(nao rejeitar H0 | H1 verdadeira)')
print()
print('Q005) Se X tem distribuicao Poisson com lambda=4, qual a variancia de X?')
print('   (a) 2')
print('   (b) 4')
print('   (c) 8')
print('   (d) 16')
print()
print('Q006) Correlacao de Pearson entre X e Y e r = -0.92. Qual a afirmacao CORRETA?')
print('   (a) X causa diminuicao em Y')
print('   (b) X e Y sao linearmente e inversamente relacionados')
print('   (c) 92% da variacao de Y e explicada por X')
print('   (d) Existe dependencia funcional perfeita entre X e Y')
print()
print('Q007) Qual teste e apropriado para comparar a media de duas amostras INDEPENDENTES, com distribuicoes aproximadamente normais e variancias desconhecidas?')
print('   (a) Teste z')
print('   (b) Teste t de Welch')
print('   (c) Teste qui-quadrado')
print('   (d) Teste de Mann-Whitney')
print()
print('Q008) Um intervalo de confianca de 95% para a media populacional foi estimado como [85, 95]. Qual a interpretacao CORRETA?')
print('   (a) Ha 95% de probabilidade de que a media populacional esteja entre 85 e 95')
print('   (b) 95% dos valores da populacao estao entre 85 e 95')
print('   (c) Se repetirmos o experimento muitas vezes, 95% dos ICs construidos conterao a media real')
print('   (d) A media amostral tem 95% de probabilidade de estar entre 85 e 95')
print()
print('Q009) Em um GLM com variavel resposta binaria, qual funcao de ligacao canonica e usada?')
print('   (a) Identidade')
print('   (b) Log')
print('   (c) Logit')
print('   (d) Inversa')
print()
print('Q010) Em uma amostra de 100 observacoes, voce calculou a media amostral com erro-padrao de 2. Para reduzir o erro-padrao pela metade, quantas observacoes voce precisa?')
print('   (a) 200')
print('   (b) 300')
print('   (c) 400')
print('   (d) 1000')
print()
print('Q011) Uma variavel X tem media 50 e variancia 100. Qual a variancia de Y = 3X + 5?')
print('   (a) 100')
print('   (b) 300')
print('   (c) 900')
print('   (d) 905')
print()
print('Q012) O Teorema Central do Limite (TCL) afirma que:')
print('   (a) Toda amostra tem distribuicao Normal')
print('   (b) A distribuicao amostral da media tende a Normal conforme n cresce, dada variancia finita')
print('   (c) A populacao sempre tem distribuicao Normal')
print('   (d) A media e igual a mediana em grandes amostras')
print()
print('Q013) Qual das distribuicoes a seguir e DISCRETA?')
print('   (a) Normal')
print('   (b) Exponencial')
print('   (c) Binomial')
print('   (d) Uniforme continua')
print()
print('Q014) Correlacao e 0 entre X e Y. Isso significa que X e Y sao independentes?')
print('   (a) Sim, sempre')
print('   (b) Nao necessariamente')
print('   (c) Sim, se ambos forem normais')
print('   (d) Sim, se a amostra for grande')
print()
print('Q015) Um erro tipo I ocorre quando:')
print('   (a) Rejeitamos H0 sendo H0 verdadeira')
print('   (b) Nao rejeitamos H0 sendo H0 falsa')
print('   (c) Calculamos mal o p-valor')
print('   (d) A amostra e muito pequena')
print()
print('Q016) Para uma matriz A quadrada inversivel, qual afirmacao e SEMPRE verdadeira?')
print('   (a) det(A) = 0')
print('   (b) A tem pelo menos um autovalor nulo')
print('   (c) A e simetrica')
print('   (d) det(A) != 0')
print()
print('Q017) A mediana e MAIS adequada que a media quando:')
print('   (a) Os dados sao normais')
print('   (b) Os dados tem outliers severos ou distribuicao assimetrica')
print('   (c) Queremos medida de tendencia central para distribuicao uniforme')
print('   (d) A amostra e grande (n > 30)')
print()
print('Q018) Sobre o teste qui-quadrado de independencia:')
print('   (a) Serve para testar se uma amostra e normal')
print('   (b) Serve para testar independencia entre duas variaveis categoricas')
print('   (c) E um teste parametrico que exige normalidade')
print('   (d) E apenas para tabelas 2x2')
print()
print('Q019) Uma empresa quer testar se a taxa de conversao de um novo site e DIFERENTE da taxa do site antigo (5%). Qual hipotese alternativa?')
print('   (a) H1: p = 0.05')
print('   (b) H1: p > 0.05')
print('   (c) H1: p < 0.05')
print('   (d) H1: p != 0.05')
print()
print('Q020) Se Pearson = 0.1 e Spearman = 0.8 entre X e Y, o que concluimos?')
print('   (a) Nao ha relacao entre X e Y')
print('   (b) Pode existir relacao MONOTONICA mas nao linear')
print('   (c) Ha erro de calculo nas correlacoes')
print('   (d) X e Y sao independentes')
print()

# %%
print('='*70)
print('BLOCO 2 -- ML CONCEITUAL')
print('='*70)
print()
print('Q021) Qual a diferenca FUNDAMENTAL entre regularizacao L1 (Lasso) e L2 (Ridge)?')
print('   (a) L1 usa raiz quadrada, L2 usa modulo')
print('   (b) L1 zera coeficientes (selecao automatica); L2 encolhe mas nao zera')
print('   (c) L1 e para classificacao; L2 e para regressao')
print('   (d) L1 e computacionalmente mais rapido que L2')
print()
print('Q022) Um modelo com alto VIES e baixa VARIANCIA tipicamente:')
print('   (a) Overfitou')
print('   (b) Fez underfitting')
print('   (c) Generalizou bem')
print('   (d) Tem leakage')
print()
print('Q023) Em Random Forest, aumentar o numero de arvores de 100 para 1000 causa:')
print('   (a) Overfitting garantido')
print('   (b) Reducao continua no AUC')
print('   (c) Maior estabilidade sem overfitting adicional')
print('   (d) Reducao do tempo de treino')
print()
print('Q024) Qual algoritmo NAO e sensivel a escala das features?')
print('   (a) SVM com kernel RBF')
print('   (b) KNN')
print('   (c) Regressao Logistica com regularizacao')
print('   (d) Random Forest')
print()
print('Q025) Qual a diferenca entre Bagging e Boosting?')
print('   (a) Bagging e sequencial, Boosting e paralelo')
print('   (b) Bagging e paralelo (modelos independentes); Boosting e sequencial (cada modelo corrige o anterior)')
print('   (c) Bagging usa arvores, Boosting usa redes neurais')
print('   (d) Nao ha diferenca praticamente')
print()
print('Q026) Em XGBoost, o parametro learning_rate (eta):')
print('   (a) E o tamanho do passo no gradient boosting (quanto cada arvore contribui)')
print('   (b) So afeta o tempo de treino')
print('   (c) Deve ser sempre 1.0 para resultados otimos')
print('   (d) E equivalente ao numero de arvores')
print()
print('Q027) O que e \'Early Stopping\' em Gradient Boosting?')
print('   (a) Forcar o modelo a parar no 1o iteracao')
print('   (b) Parar o treino quando a metrica em validacao para de melhorar')
print('   (c) Definir max_depth = 1')
print('   (d) Usar apenas 50% dos dados')
print()
print('Q028) Qual a funcao de custo de Regressao Logistica?')
print('   (a) Soma dos quadrados dos erros')
print('   (b) Entropia cruzada (log loss)')
print('   (c) Erro medio absoluto')
print('   (d) Hinge loss')
print()
print('Q029) Por que Random Forest NAO precisa de cross-validation para estimar generalizacao?')
print('   (a) Porque nunca overfitta')
print('   (b) Porque tem OOB (Out-of-Bag) score embutido')
print('   (c) Porque usa todo o dataset para treino')
print('   (d) Nao e verdade -- sempre precisa de CV')
print()
print('Q030) O que SHAP values representam?')
print('   (a) Importancia global das features')
print('   (b) Contribuicao marginal de cada feature para a previsao de UMA observacao')
print('   (c) Correlacao entre features')
print('   (d) Valores de teste estatistico')
print()
print('Q031) Em Naive Bayes, qual a premissa \'naive\' (ingenua)?')
print('   (a) Que os dados sao normais')
print('   (b) Que todas as classes sao igualmente provaveis')
print('   (c) Que as features sao CONDICIONALMENTE INDEPENDENTES dada a classe')
print('   (d) Que nao ha ausentes nos dados')
print()
print('Q032) Sobre KNN (K Nearest Neighbors):')
print('   (a) E um modelo parametrico')
print('   (b) E um modelo NAO-parametrico e preguicoso (lazy)')
print('   (c) Treina rapidamente mas prediz devagar')
print('   (d) (b) e (c) estao corretas')
print()
print('Q033) Em uma tarefa de deteccao de fraude com 99.9% de transacoes legitimas, qual NAO e uma estrategia adequada para desbalanceamento?')
print('   (a) class_weight=\'balanced\'')
print('   (b) scale_pos_weight no XGBoost')
print('   (c) Maximizar acuracia')
print('   (d) SMOTE ou ADASYN')
print()
print('Q034) O que e \'Data Leakage\' (vazamento de dados)?')
print('   (a) Perda de dados por falha tecnica')
print('   (b) Quando o modelo aprende informacao que nao estaria disponivel no momento real da previsao')
print('   (c) Features com muitos ausentes')
print('   (d) Correlacao entre features')
print()
print('Q035) Qual o impacto de NORMALIZAR os dados ANTES do split treino/teste?')
print('   (a) Nenhum')
print('   (b) Melhora a performance')
print('   (c) Causa data leakage (a media e desvio vem de todos os dados)')
print('   (d) So afeta modelos de arvore')
print()
print('Q036) Qual dos seguintes modelos e tipicamente o MELHOR para dados tabulares estruturados, superando deep learning?')
print('   (a) Redes neurais profundas (MLP)')
print('   (b) XGBoost / LightGBM')
print('   (c) SVM linear')
print('   (d) Regressao Logistica')
print()
print('Q037) Em PCA, o que o primeiro componente principal (PC1) representa?')
print('   (a) A feature mais importante')
print('   (b) A direcao de MAIOR variancia no dado')
print('   (c) A media das features')
print('   (d) O outlier mais extremo')
print()
print('Q038) Sobre DBSCAN:')
print('   (a) Requer numero de clusters pre-definido')
print('   (b) Nao identifica outliers')
print('   (c) Identifica clusters de forma arbitraria e marca outliers como ruido')
print('   (d) E deterministico para qualquer parametro')
print()
print('Q039) Qual a principal vantagem do Gradient Boosting sobre Random Forest?')
print('   (a) Mais rapido para treinar')
print('   (b) Nao overfitta')
print('   (c) Tende a ter maior poder preditivo em dados tabulares')
print('   (d) Nao precisa de hiperparametros')
print()
print('Q040) Em redes neurais, qual funcao de ativacao tem o problema de \'dying ReLU\'?')
print('   (a) Sigmoid')
print('   (b) Tanh')
print('   (c) ReLU')
print('   (d) Softmax')
print()

# %%
print('='*70)
print('BLOCO 3 -- REGRESSAO')
print('='*70)
print()
print('Q041) Em ElasticNet, o parametro l1_ratio controla:')
print('   (a) O tamanho da amostra')
print('   (b) A proporcao entre L1 e L2 na regularizacao')
print('   (c) A taxa de aprendizado')
print('   (d) O numero de features')
print()
print('Q042) Se voce treina ElasticNet com alpha=1.0 e l1_ratio=0.01, qual efeito predomina?')
print('   (a) L1 (Lasso) -- selecao de features')
print('   (b) L2 (Ridge) -- encolhimento suave')
print('   (c) Sem regularizacao')
print('   (d) Equivalente a OLS')
print()
print('Q043) No SVR com kernel linear e C=0.001, a regularizacao e:')
print('   (a) Muito fraca')
print('   (b) Muito forte')
print('   (c) Sem regularizacao')
print('   (d) Balanceada')
print()
print('Q044) Adicionar uma variavel irrelevante ao modelo linear causa:')
print('   (a) R^2 sempre aumenta (ou fica igual)')
print('   (b) R^2 diminui')
print('   (c) Pode aumentar ou diminuir R^2')
print('   (d) R^2 permanece sempre igual')
print()
print('Q045) Qual metrica e INADEQUADA quando o alvo pode ter valor zero?')
print('   (a) RMSE')
print('   (b) MAE')
print('   (c) R^2')
print('   (d) MAPE')
print()
print('Q046) Voce ajusta Ridge com alpha muito grande. Os coeficientes tendem a:')
print('   (a) Infinito')
print('   (b) Zero')
print('   (c) Valores de OLS')
print('   (d) 1.0')
print()
print('Q047) Em regressao linear, o coeficiente beta_1 = 3.5 com p-valor = 0.001 significa:')
print('   (a) Cada unidade de X_1 aumenta Y em 3.5 unidades, mantendo outras variaveis constantes')
print('   (b) 35% de Y e explicado por X_1')
print('   (c) Ha 99.9% de probabilidade de X_1 ser importante')
print('   (d) A correlacao entre X_1 e Y e 3.5')
print()
print('Q048) Homocedasticidade em regressao significa:')
print('   (a) Residuos seguem distribuicao normal')
print('   (b) Variancia dos residuos e constante ao longo dos valores previstos')
print('   (c) Residuos tem media zero')
print('   (d) Residuos sao independentes')
print()
print('Q049) Ao adicionar features correlacionadas (multicolinearidade):')
print('   (a) R^2 cai')
print('   (b) Predicoes ficam menos precisas')
print('   (c) Coeficientes individuais ficam instaveis (variancia alta), mas predicoes podem ser OK')
print('   (d) O modelo nao converge')
print()
print('Q050) O \'coeficiente de determinacao ajustado\' (R^2 ajustado):')
print('   (a) E sempre igual ao R^2')
print('   (b) E sempre menor ou igual ao R^2')
print('   (c) Pode ser maior que R^2 se as features sao relevantes')
print('   (d) Nao e util para comparar modelos')
print()
print('Q051) Regressao Poisson e apropriada quando o alvo e:')
print('   (a) Binario (0/1)')
print('   (b) Contagem (0, 1, 2, 3, ...)')
print('   (c) Continuo e normal')
print('   (d) Proporcoes entre 0 e 1')
print()
print('Q052) Em Lasso (L1), se voce reduz alpha para zero, o modelo tende a:')
print('   (a) OLS padrao')
print('   (b) Ridge')
print('   (c) Todos os coeficientes zero')
print('   (d) Modelo sem intercepto')
print()
print('Q053) Ao escolher entre Ridge e Lasso:')
print('   (a) Sempre use Ridge')
print('   (b) Use Lasso quando quiser selecao automatica de features')
print('   (c) Use Lasso para melhorar previsao sempre')
print('   (d) Ridge e Lasso produzem resultados identicos')
print()
print('Q054) Voce tem 10.000 features e 500 observacoes. Qual tecnica seria INADEQUADA?')
print('   (a) Lasso para selecao de features')
print('   (b) PCA antes do modelo')
print('   (c) OLS sem regularizacao')
print('   (d) ElasticNet')
print()
print('Q055) Em uma regressao com log-transformacao do alvo, o coeficiente beta = 0.05 significa aproximadamente:')
print('   (a) Aumento de 0.05 unidades em Y')
print('   (b) Aumento de 5% em Y para cada unidade de X')
print('   (c) Aumento de 5 unidades em Y')
print('   (d) Reducao de 5% em Y')
print()

# %%
print('='*70)
print('BLOCO 4 -- CLASSIFICACAO')
print('='*70)
print()
print('Q056) Em Regressao Logistica com C=0.1 e penalty=\'l2\', voce esta aplicando:')
print('   (a) Regularizacao L1 forte')
print('   (b) Regularizacao L2 moderada a forte (C=1/alpha)')
print('   (c) Sem regularizacao')
print('   (d) ElasticNet')
print()
print('Q057) Qual a funcao sigmoide usada em regressao logistica?')
print('   (a) f(z) = z')
print('   (b) f(z) = 1 / (1 + exp(-z))')
print('   (c) f(z) = max(0, z)')
print('   (d) f(z) = exp(z) / sum(exp(z))')
print()
print('Q058) A razao de chances (Odds Ratio) em regressao logistica com beta=0.5 e:')
print('   (a) 0.5')
print('   (b) 1.5')
print('   (c) exp(0.5) ~ 1.65')
print('   (d) log(0.5)')
print()
print('Q059) Em arvore de classificacao, qual criterio NAO e usado para split?')
print('   (a) Entropia (Gain Ratio)')
print('   (b) Indice de Gini')
print('   (c) Reducao na SSE (Soma dos Erros ao Quadrado)')
print('   (d) Todos sao usados em classificacao')
print()
print('Q060) Uma arvore de classificacao SEM PODA no dataset de treino apresenta:')
print('   (a) Log Loss ~ 0 (proximo de zero)')
print('   (b) AUC = 0.5')
print('   (c) Precision = Recall = 0.5')
print('   (d) Acuracia proxima de 50%')
print()
print('Q061) Em um problema binario com 95% de classe 0 e 5% de classe 1, voce obtem 95% de acuracia. O que isso significa?')
print('   (a) Modelo otimo')
print('   (b) Talvez o modelo so preveja classe 0 (nao aprendeu nada util)')
print('   (c) Excelente modelo')
print('   (d) Overfitting')
print()
print('Q062) Qual metrica FAZ SENTIDO em deteccao de fraude (1% positivos)?')
print('   (a) Acuracia')
print('   (b) AUC-ROC + Precision/Recall + F1 + metricas de custo')
print('   (c) Apenas MAE')
print('   (d) Apenas RMSE')
print()
print('Q063) Ao ajustar threshold de decisao de 0.5 para 0.3 em classificacao binaria:')
print('   (a) Precision aumenta, Recall diminui')
print('   (b) Precision diminui, Recall aumenta')
print('   (c) Ambos aumentam')
print('   (d) Sem mudanca')
print()
print('Q064) Matriz de confusao: TP=40, FP=10, TN=80, FN=20. Qual o F1?')
print('   (a) 0.73')
print('   (b) 0.67')
print('   (c) 0.80')
print('   (d) 0.50')
print()
print('Q065) AUC-ROC = 0.50 significa:')
print('   (a) Modelo perfeito')
print('   (b) Modelo aleatorio (sem poder discriminativo)')
print('   (c) Acuracia de 50%')
print('   (d) Probabilidade de acerto = 50%')
print()
print('Q066) Em XGBoost, scale_pos_weight e usado para:')
print('   (a) Normalizar features')
print('   (b) Definir taxa de aprendizado')
print('   (c) Compensar desbalanceamento de classes')
print('   (d) Limitar profundidade das arvores')
print()
print('Q067) Em classificacao multiclasse com Regressao Logistica, o padrao OvR significa:')
print('   (a) One-vs-Rest: treina um classificador binario por classe')
print('   (b) One-vs-Regression')
print('   (c) One-vs-Root')
print('   (d) Order-vs-Rule')
print()
print('Q068) Qual o efeito de aumentar max_depth em XGBoost?')
print('   (a) Modelo mais simples, mais viés, menos variância')
print('   (b) Modelo mais complexo, menos viés, mais variância (risco de overfitting)')
print('   (c) Sem efeito')
print('   (d) Só afeta tempo de treino')
print()
print('Q069) A log loss (entropia cruzada binaria) para uma previsao p=0.9 em y_real=1 e aproximadamente:')
print('   (a) 0.1')
print('   (b) 0.9')
print('   (c) -ln(0.9) ~ 0.105')
print('   (d) 1.0')
print()
print('Q070) Calibracao de modelo significa:')
print('   (a) Ajustar o modelo ao dataset')
print('   (b) Fazer P=0.3 corresponder a 30% de positivos reais')
print('   (c) Treinar varias vezes para estabilidade')
print('   (d) Aplicar cross-validation')
print()

# %%
print('='*70)
print('BLOCO 5 -- VALIDACAO E METRICAS')
print('='*70)
print()
print('Q071) Qual a diferenca entre K-Fold e Stratified K-Fold?')
print('   (a) Nenhuma')
print('   (b) Stratified preserva a proporcao de classes em cada fold')
print('   (c) K-Fold e mais rapido')
print('   (d) Stratified so funciona para K=10')
print()
print('Q072) Leave-One-Out Cross-Validation (LOOCV) e:')
print('   (a) K-Fold com K=N (cada observacao e um fold)')
print('   (b) Split simples 80/20')
print('   (c) Hold-out com 10%')
print('   (d) Validacao sem teste')
print()
print('Q073) Em dados com componente TEMPORAL, qual validacao e mais adequada?')
print('   (a) KFold aleatorio')
print('   (b) StratifiedKFold')
print('   (c) TimeSeriesSplit (split temporal)')
print('   (d) GroupKFold')
print()
print('Q074) Quando MESMA ENTIDADE aparece em varias linhas (ex: mesmo CNPJ em meses diferentes), voce deve usar:')
print('   (a) KFold padrao')
print('   (b) GroupKFold com groups=cnpj')
print('   (c) StratifiedKFold')
print('   (d) Shuffle e split aleatorio')
print()
print('Q075) Em cross_validate do sklearn, quando voce usa scoring=\'neg_mean_squared_error\', o valor retornado e:')
print('   (a) O MSE real (positivo)')
print('   (b) O negativo do MSE (para que maior seja melhor)')
print('   (c) Zero')
print('   (d) Indefinido')
print()
print('Q076) Um modelo tem AUC=0.85 no treino e AUC=0.73 no teste. Este e um caso de:')
print('   (a) Underfitting')
print('   (b) Overfitting moderado')
print('   (c) Generalizacao perfeita')
print('   (d) Leakage')
print()
print('Q077) O AUC-PR (Precision-Recall AUC) e mais informativo que AUC-ROC quando:')
print('   (a) Os dados sao balanceados')
print('   (b) Os dados sao muito desbalanceados (classe positiva rara)')
print('   (c) Ha muitas features')
print('   (d) Nunca')
print()
print('Q078) KS (Kolmogorov-Smirnov) em modelos de credito mede:')
print('   (a) Normalidade dos residuos')
print('   (b) Separacao maxima entre distribuicoes acumuladas de positivos e negativos')
print('   (c) Multicolinearidade')
print('   (d) Heterocedasticidade')
print()
print('Q079) Em cross-validation, voce aplica normalizacao (StandardScaler). Qual abordagem CORRETA?')
print('   (a) Fit do scaler em todo o treino, transform no teste')
print('   (b) Dentro do Pipeline: scaler + modelo, fit/transform por fold')
print('   (c) Fit em todo o dataset (treino + teste)')
print('   (d) Nao normalizar')
print()
print('Q080) O Gini em modelos de classificacao esta relacionado ao AUC por:')
print('   (a) Gini = AUC')
print('   (b) Gini = 2*AUC - 1')
print('   (c) Gini = 1 - AUC')
print('   (d) Gini = AUC^2')
print()

# %%
print('='*70)
print('BLOCO 6 -- CLUSTERING, PCA, NAO-SUPERVISIONADO')
print('='*70)
print()
print('Q081) Em K-means, o que determina a posicao final dos centroides?')
print('   (a) Media dos pontos atribuidos a cada cluster, iterativamente ate convergencia')
print('   (b) Mediana dos pontos')
print('   (c) Ponto mais denso')
print('   (d) Aleatoriedade')
print()
print('Q082) Qual metodo ajuda a escolher o numero ideal de clusters (K) em K-means?')
print('   (a) Metodo do cotovelo (elbow)')
print('   (b) Silhueta')
print('   (c) Gap statistic')
print('   (d) Todas acima')
print()
print('Q083) Em clustering hierarquico Single Linkage, a distancia entre dois clusters e:')
print('   (a) Distancia maxima entre pontos')
print('   (b) Distancia MINIMA entre pontos (um de cada cluster)')
print('   (c) Distancia entre centroides')
print('   (d) Media das distancias par a par')
print()
print('Q084) Complete Linkage usa:')
print('   (a) Distancia minima')
print('   (b) Distancia MAXIMA entre pontos')
print('   (c) Centroides')
print('   (d) Medias')
print()
print('Q085) Average Linkage usa:')
print('   (a) Distancia entre centroides')
print('   (b) Distancia minima')
print('   (c) MEDIA das distancias par a par entre pontos')
print('   (d) Distancia maxima')
print()
print('Q086) DBSCAN identifica clusters baseado em:')
print('   (a) Distancia Euclidiana ao centroide')
print('   (b) Densidade local (eps e min_samples)')
print('   (c) Distribuicoes Gaussianas')
print('   (d) Arvore hierarquica')
print()
print('Q087) Em PCA, a variancia explicada pelos K primeiros componentes pode ser calculada como:')
print('   (a) Soma dos autovalores dos K primeiros / soma de todos autovalores')
print('   (b) K / numero total de features')
print('   (c) Raiz dos autovalores')
print('   (d) Produto dos autovalores')
print()
print('Q088) Qual limitacao importante do K-means?')
print('   (a) Requer K pre-definido, assume clusters esfericos de tamanhos similares')
print('   (b) E lento em datasets grandes')
print('   (c) Nao converge')
print('   (d) So funciona em dimensao 2')
print()
print('Q089) Gaussian Mixture Models (GMM) diferem do K-means porque:')
print('   (a) GMM e mais rapido')
print('   (b) GMM usa EM algoritmo e atribui probabilidades a cada cluster (soft assignment)')
print('   (c) GMM nao precisa de K')
print('   (d) K-means usa distribuicoes normais')
print()
print('Q090) O dendrograma de clustering hierarquico:')
print('   (a) Mostra como usar K-means')
print('   (b) Mostra a hierarquia de agrupamentos e permite cortar em qualquer nivel para obter K clusters')
print('   (c) E um tipo de histograma')
print('   (d) Mostra apenas outliers')
print()

# %%
print('='*70)
print('BLOCO 7 -- SQL, ENGENHARIA DE DADOS, PYTHON')
print('='*70)
print()
print('Q091) Em SQL, qual a diferenca entre INNER JOIN e LEFT JOIN?')
print('   (a) Nenhuma')
print('   (b) INNER retorna so registros com correspondencia; LEFT retorna todos do lado esquerdo')
print('   (c) LEFT e mais rapido')
print('   (d) INNER e para uma tabela, LEFT para varias')
print()
print('Q092) Qual query SQL retorna o CNPJ com MAIOR volume total?')
print('   (a) SELECT cnpj FROM transacoes ORDER BY valor DESC LIMIT 1')
print('   (b) SELECT cnpj, SUM(valor) FROM transacoes GROUP BY cnpj ORDER BY SUM(valor) DESC LIMIT 1')
print('   (c) SELECT TOP 1 cnpj FROM transacoes')
print('   (d) SELECT cnpj, MAX(valor) FROM transacoes')
print()
print('Q093) Em Pandas, df.groupby(\'col\').agg({\'valor\': \'mean\'}) retorna:')
print('   (a) Media de valor ignorando col')
print('   (b) Media de valor agrupada por col')
print('   (c) Apenas a coluna col')
print('   (d) Erro')
print()
print('Q094) df.isnull().sum() retorna:')
print('   (a) Total de linhas')
print('   (b) Numero de valores ausentes por coluna')
print('   (c) Apenas booleanos')
print('   (d) Erro')
print()
print('Q095) Em PySpark, a diferenca entre DataFrame e RDD:')
print('   (a) Nao ha diferenca')
print('   (b) DataFrame tem schema (tipado) e usa Catalyst optimizer; RDD e mais baixo nivel')
print('   (c) RDD e mais rapido sempre')
print('   (d) DataFrame nao existe em PySpark')
print()
print('Q096) Em Python, qual a complexidade MEDIA de busca em dicionario (dict)?')
print('   (a) O(1)')
print('   (b) O(log n)')
print('   (c) O(n)')
print('   (d) O(n^2)')
print()
print('Q097) Em um pipeline ETL no Itau, o que significa \'point-in-time correctness\'?')
print('   (a) Garantir timestamp na feature')
print('   (b) Garantir que para cada evento (ex: cliente em 01/jun), so usamos features disponiveis ATE aquela data')
print('   (c) Sincronizar relogios dos servidores')
print('   (d) Usar horario de Brasilia')
print()
print('Q098) Qual ferramenta da AWS e usada para SQL em dados no S3?')
print('   (a) EC2')
print('   (b) Athena')
print('   (c) Lambda')
print('   (d) IAM')
print()
print('Q099) Em SageMaker, Endpoint real-time vs Batch Transform:')
print('   (a) Endpoint: decisoes em <100ms. Batch: scoring de grandes volumes offline')
print('   (b) Batch e mais rapido sempre')
print('   (c) Endpoint e gratis')
print('   (d) Nao ha diferenca')
print()
print('Q100) Em uma arquitetura de ML em producao no banco, qual e a ORDEM logica do pipeline?')
print('   (a) Modelo -> Monitoring -> Features -> Dados')
print('   (b) Dados -> Features -> Modelo -> Deploy -> Monitoring')
print('   (c) Monitoring -> Dados -> Modelo -> Features')
print('   (d) Deploy -> Dados -> Modelo -> Features')
print()

# %% [markdown]
# ---
# ## Registro das suas respostas
#
# Use a celula abaixo para anotar suas respostas ANTES de ver o gabarito.
# Edite a string com suas respostas no formato: 'Q01: (a)', 'Q02: (c)', etc.
#
# Depois execute o script de correcao na celula seguinte do gabarito.

# %%
# REGISTRE SUAS RESPOSTAS AQUI
# Substitua 'None' pela sua resposta: '(a)', '(b)', '(c)' ou '(d)'
# Se quiser deixar em branco (sem penalidade), deixe None

minhas_respostas = {
    # Bloco 1 -- Estatistica
    1: None, 2: None, 3: None, 4: None, 5: None,
    6: None, 7: None, 8: None, 9: None, 10: None,
    11: None, 12: None, 13: None, 14: None, 15: None,
    16: None, 17: None, 18: None, 19: None, 20: None,
    # Bloco 2 -- ML Conceitual
    21: None, 22: None, 23: None, 24: None, 25: None,
    26: None, 27: None, 28: None, 29: None, 30: None,
    31: None, 32: None, 33: None, 34: None, 35: None,
    36: None, 37: None, 38: None, 39: None, 40: None,
    # Bloco 3 -- Regressao
    41: None, 42: None, 43: None, 44: None, 45: None,
    46: None, 47: None, 48: None, 49: None, 50: None,
    51: None, 52: None, 53: None, 54: None, 55: None,
    # Bloco 4 -- Classificacao
    56: None, 57: None, 58: None, 59: None, 60: None,
    61: None, 62: None, 63: None, 64: None, 65: None,
    66: None, 67: None, 68: None, 69: None, 70: None,
    # Bloco 5 -- Validacao e Metricas
    71: None, 72: None, 73: None, 74: None, 75: None,
    76: None, 77: None, 78: None, 79: None, 80: None,
    # Bloco 6 -- Clustering, PCA
    81: None, 82: None, 83: None, 84: None, 85: None,
    86: None, 87: None, 88: None, 89: None, 90: None,
    # Bloco 7 -- SQL, Python
    91: None, 92: None, 93: None, 94: None, 95: None,
    96: None, 97: None, 98: None, 99: None, 100: None,
}

print(f'Voce respondeu {sum(1 for v in minhas_respostas.values() if v is not None)} de 100 questoes')

# %% [markdown]
# ---
# ## GABARITO COMENTADO E CORRECAO AUTOMATICA
#
# Nao olhe o gabarito ate ter respondido!
#
# A celula abaixo:
# 1. Corrige suas respostas aplicando o sistema de penalidade do Itau (errada anula certa)
# 2. Mostra sua pontuacao por bloco
# 3. Lista as questoes erradas com a explicacao detalhada
# 4. Da um diagnostico final

# %%
gabarito = {
    1: ('(b)', 'Regra dos 68-95-99.7: 1 desvio-padrao = 68%. Como 85 e 115 estao a 1 sigma da media (100 +/- 15), a probabilidade e ~68%.'),
    2: ('(c)', 'n ensaios de Bernoulli independentes com probabilidade fixa p = Binomial(n, p). Aqui n=50 e p=0.5.'),
    3: ('(b)', 'p-valor < alpha (0.03 < 0.05) => rejeita H0. (a) e (c) sao interpretacoes INCORRETAS classicas de p-valor. P-valor e P(observar dados | H0 verdadeira), nao P(H0 verdadeira).'),
    4: ('(b)', 'Poder = 1 - beta = probabilidade de detectar um efeito REAL. (a) e alpha (erro tipo 1), (d) e beta (erro tipo 2).'),
    5: ('(b)', 'Na Poisson, E[X] = Var[X] = lambda. Essa igualdade e caracteristica da Poisson.'),
    6: ('(b)', 'Correlacao mede associacao linear. Negativa = inversa. (a) correlacao nao e causalidade. (c) e R^2=0.85, nao 0.92. (d) perfeita exigiria |r|=1.'),
    7: ('(b)', 'Teste z assume variancia conhecida. Mann-Whitney e nao-parametrico (sem premissa de normalidade). Qui-quadrado e para variaveis categoricas. Welch e o t-test classico quando variancias sao desconhecidas e podem ser diferentes.'),
    8: ('(c)', '(a) E erro classico. A media populacional e fixa, nao aleatoria. O IC e aleatorio. (c) e a interpretacao frequentista correta.'),
    9: ('(c)', 'Para binaria: Bernoulli + funcao canonica logit = regressao logistica. Identidade e para Gaussian (linear). Log e para Poisson. Inversa e para Gamma.'),
    10: ('(c)', 'Erro-padrao = sigma/sqrt(n). Para reduzir pela metade: sqrt(n_novo) = 2*sqrt(100) => n_novo = 4*100 = 400. Regra do 4x.'),
    11: ('(c)', 'Var(aX + b) = a^2 * Var(X). Logo Var(3X + 5) = 9 * 100 = 900. A constante b nao afeta variancia.'),
    12: ('(b)', 'TCL e sobre a distribuicao da MEDIA AMOSTRAL, nao sobre a populacao original. (a) e (c) estao errados. A populacao pode ser qualquer distribuicao com variancia finita.'),
    13: ('(c)', 'Binomial e soma de Bernoullis (0/1) -> so assume valores inteiros. Normal, Exponencial e Uniforme continua sao continuas.'),
    14: ('(b)', 'Correlacao zero NAO implica independencia. Exemplo: Y = X^2 tem correlacao zero mas Y depende de X completamente. (c) so e verdade se X e Y sao CONJUNTAMENTE normais.'),
    15: ('(a)', 'Erro tipo I (alpha) = rejeitar H0 quando H0 e verdadeira (falso positivo). (b) e erro tipo II.'),
    16: ('(d)', 'Matriz inversivel <=> det != 0 <=> nenhum autovalor nulo. (a), (b) sao FALSAS. (c) nao e obrigatoria.'),
    17: ('(b)', 'Mediana e ROBUSTA a outliers. Para dados com cauda pesada ou outliers: use mediana. Para normais simetricos: media e mediana sao iguais.'),
    18: ('(b)', 'Qui-quadrado de independencia testa se duas categoricas sao independentes. E nao-parametrico. Funciona para tabelas NxM quaisquer.'),
    19: ('(d)', "'Diferente' implica teste BICAUDAL: p != 0.05. (b) e (c) sao unicaudais. (a) e H0."),
    20: ('(b)', 'Pearson mede relacao LINEAR. Spearman mede relacao MONOTONICA (incluindo nao-linear). Pearson baixo + Spearman alto = relacao monotonica nao-linear (ex: Y = exp(X)).'),
    21: ('(b)', 'L1 (|beta|) produz solucoes esparsas (selecao automatica de features). L2 (beta^2) encolhe suavemente mas nao zera. Essa e a diferenca essencial.'),
    22: ('(b)', 'Vies alto = modelo simples demais = underfitting. Variancia alta = modelo complexo demais = overfitting.'),
    23: ('(c)', 'Em RF, mais arvores = mais estabilidade (redu variancia). NAO causa overfitting adicional. Overfitting em RF vem de max_depth alto, nao n_estimators.'),
    24: ('(d)', 'Arvores (e ensembles de arvores) fazem splits por feature individual. Escala nao importa. SVM, KNN e Regressao Regularizada TODOS exigem normalizacao.'),
    25: ('(b)', 'Bagging = Bootstrap Aggregating = treina modelos INDEPENDENTES em bootstraps do dado. Boosting = treina SEQUENCIALMENTE, cada modelo corrige os erros do anterior.'),
    26: ('(a)', 'Learning rate = peso de cada arvore na soma final. Menor eta + mais arvores = melhor generalizacao (com mais custo computacional).'),
    27: ('(b)', 'Early stopping monitora a metrica em validacao. Se nao melhora por N iteracoes seguidas, para o treino. Previne overfitting e economiza tempo.'),
    28: ('(b)', 'Logistica minimiza a Log Loss (entropia cruzada binaria). Hinge e do SVM. Soma dos quadrados e OLS (regressao linear).'),
    29: ('(b)', 'RF usa bootstrap. Cada arvore deixa ~37% dos dados de fora (out-of-bag). A media do erro nesses pontos da estimativa honesta de generalizacao SEM precisar de CV externo.'),
    30: ('(b)', 'SHAP values explicam previsoes INDIVIDUAIS: quanto cada feature contribuiu (positiva ou negativa) para aquele score especifico. Baseado em teoria dos jogos (Shapley values).'),
    31: ('(c)', "Naive Bayes assume P(x1,x2,...xn | y) = produto de P(xi | y). Essa e a premissa 'naive' -- raramente verdadeira, mas o modelo funciona surpreendentemente bem."),
    32: ('(d)', "KNN nao aprende parametros (nao-parametrico). 'Lazy' porque nao faz trabalho no treino -- so armazena. Na previsao, calcula distancias com todo o dataset (caro)."),
    33: ('(c)', 'Acuracia em base desbalanceada e ENGANOSA: modelo idiota que preve sempre 0 tem 99.9% de acuracia. As outras opcoes sao tecnicas legitimas.'),
    34: ('(b)', 'Leakage = informacao do futuro ou do target infiltrada nas features. Modelo parece otimo em validacao mas falha em producao.'),
    35: ('(c)', 'Normalizar antes do split = usar estatisticas do TESTE no calculo -> leakage. Correto: split primeiro, depois Pipeline com StandardScaler.'),
    36: ('(b)', 'Em dados tabulares, Gradient Boosting (XGBoost, LightGBM, CatBoost) domina benchmarks. Deep learning so vence em dados nao-estruturados (imagem, texto, audio).'),
    37: ('(b)', 'PCA encontra direcoes ortogonais que maximizam variancia. PC1 e a direcao que captura a MAIOR variancia. PC2 e ortogonal a PC1 e captura a segunda maior, e assim por diante.'),
    38: ('(c)', 'DBSCAN nao precisa de k. Baseia-se em densidade: clusters de qualquer forma, pontos isolados = ruido. Parametros: eps e min_samples.'),
    39: ('(c)', "GB aprende sequencialmente, corrigindo erros -> geralmente maior poder preditivo. Mas: mais sensivel a hiperparametros, mais tempo de tuning. RF e 'set and forget'."),
    40: ('(c)', 'ReLU = max(0, x). Se muitos neuronios recebem input negativo, ficam em 0 permanentemente (nao propagam gradiente). Leaky ReLU e PReLU corrigem isso.'),
    41: ('(b)', 'ElasticNet = alpha * [l1_ratio * L1 + (1 - l1_ratio) * L2]. l1_ratio = 1 -> puro Lasso. l1_ratio = 0 -> puro Ridge.'),
    42: ('(b)', 'l1_ratio=0.01 => 99% do peso e L2. Regularizacao e praticamente Ridge. ESSA E A Q10 DA PROVA DE 2019.'),
    43: ('(b)', 'No SVM/SVR, C = 1/alpha. C=0.001 -> regularizacao MUITO forte. ESSA E A LOGICA DA Q11 DA PROVA DE 2019.'),
    44: ('(a)', 'R^2 NUNCA diminui ao adicionar variaveis. Por isso usamos R^2 AJUSTADO que penaliza complexidade. Essa e uma pegadinha classica.'),
    45: ('(d)', 'MAPE = media |y - y_pred|/|y|. Com y=0 -> divisao por zero -> indefinido. Use RMSE, MAE ou R^2.'),
    46: ('(b)', 'Alpha -> infinito em Ridge => penalidade domina => coeficientes -> zero. ESSA E A PEGADINHA DA Q14 DA PROVA DE 2019 -- candidatos escolhem (a)!'),
    47: ('(a)', "Interpretacao correta: 'ceteris paribus' (mantidas outras constantes). (b) confunde com R^2 parcial. (c) e erro de p-valor. (d) correlacao e entre -1 e 1."),
    48: ('(b)', 'Homo (igual) + cedastico (variancia). Variancia constante dos erros. Violacao = heterocedasticidade, exige correcao (transformacao ou regressao robusta).'),
    49: ('(c)', 'Multicolinearidade nao prejudica muito a PREDICAO mas destroi a INTERPRETABILIDADE: pequenas mudancas no dado mudam muito os coeficientes. Detectar com VIF.'),
    50: ('(b)', 'R^2 ajustado = 1 - (1-R^2) * (n-1)/(n-k-1). Sempre <= R^2. Igual apenas quando o modelo so tem intercepto.'),
    51: ('(b)', 'Regressao Poisson e para dados de contagem: numero de eventos em um intervalo. Variavel resposta inteira nao-negativa.'),
    52: ('(a)', 'Alpha = 0 em Lasso ou Ridge => SEM regularizacao => OLS (Ordinary Least Squares). Alpha maior = mais encolhimento.'),
    53: ('(b)', 'Lasso zera coeficientes -> selecao de features. Use quando ha muitas features e voce espera que algumas sejam irrelevantes. Ridge encolhe suavemente todos.'),
    54: ('(c)', 'OLS com p > n (features > observacoes) e mal condicionado ou impossivel. Lasso, PCA ou ElasticNet sao solucoes padrao para esse cenario.'),
    55: ('(b)', 'log(Y) = beta * X + ... => Y = exp(beta * X). Para beta pequeno, aumento em X causa aumento percentual em Y ~ 100*beta% = 5%.'),
    56: ('(b)', 'No sklearn, C = 1/alpha. C=0.1 => alpha=10 (regularizacao FORTE). ESSA E A LOGICA DA Q21 DA PROVA DE 2019.'),
    57: ('(b)', 'Sigmoide mapeia logits reais para [0, 1]. (c) e ReLU, (d) e softmax (multiclasse).'),
    58: ('(c)', 'OR = exp(beta). beta=0.5 => OR = e^0.5 ~ 1.65. Cada unidade de X multiplica as odds de Y=1 por 1.65.'),
    59: ('(c)', 'SSE e de REGRESSAO (arvore de regressao). Classificacao usa entropia ou Gini. Pegadinha comum.'),
    60: ('(a)', 'Sem poda, a arvore cria folhas puras (todas as observacoes da folha sao da mesma classe). P(classe correta) = 1.0 no treino. -log(1) = 0. Log Loss ~ 0. ESSA E A LOGICA DA Q20 DA PROVA DE 2019.'),
    61: ('(b)', 'Classe majoritaria em 95% = baseline trivial. Se sua acuracia = taxa da majoritaria, o modelo NAO APRENDEU NADA. Sempre compare com o baseline trivial.'),
    62: ('(b)', 'Acuracia e enganosa em desbalanceados. AUC-ROC e invariante a desbalanceamento. Precision e Recall por classe capturam o trade-off. Custo monetario e o que importa no fim.'),
    63: ('(b)', 'Threshold menor = mais classificados como positivos = captura mais verdadeiros (Recall sobe) mas tambem mais falsos (Precision cai). Trade-off classico.'),
    64: ('(a)', 'Precision = 40/50 = 0.8. Recall = 40/60 = 0.67. F1 = 2 * 0.8 * 0.67 / (0.8 + 0.67) = 1.072/1.47 = 0.73.'),
    65: ('(b)', 'AUC = 0.5 = area de uma ROC diagonal = modelo aleatorio. AUC = 1.0 = perfeito. AUC < 0.5 = pior que aleatorio (modelo invertido).'),
    66: ('(c)', 'scale_pos_weight = n_negativos/n_positivos. Compensa o desbalanceamento sem precisar de SMOTE. Mais honesto do que criar dados sinteticos.'),
    67: ('(a)', "OvR (ou OvA = One-vs-All): para cada classe k, treina um classificador k vs 'todas as outras'. Alternativa: multinomial softmax."),
    68: ('(b)', 'max_depth controla complexidade por arvore. Mais profundo = mais capturas de interacoes = mais risco de overfitting. Tipicamente 3-8.'),
    69: ('(c)', 'Log Loss = -y*log(p) - (1-y)*log(1-p). Para y=1, p=0.9: -1 * ln(0.9) ~ 0.105. Para y=1, p=0.1: -ln(0.1) ~ 2.30 (punicao severa).'),
    70: ('(b)', 'Modelo calibrado: P prevista corresponde a taxa real. Importante para banco (provisao, pricing). Metodos: Platt Scaling, Isotonic. AUC pode ser alto mesmo com ma calibracao.'),
    71: ('(b)', 'Stratified K-Fold garante que cada fold tem mesma proporcao de classes que o dataset completo. Essencial para classes desbalanceadas.'),
    72: ('(a)', 'LOOCV = N-Fold. Para cada observacao, treina nos outros N-1 e testa nela. Muito caro computacionalmente para N grande.'),
    73: ('(c)', 'Dados temporais: JAMAIS use split aleatorio (leakage temporal). Use TimeSeriesSplit ou janela deslizante: treina no passado, testa no futuro.'),
    74: ('(b)', 'GroupKFold garante que a mesma entidade nao aparece em treino E teste. Sem isso, leakage silencioso infla AUC.'),
    75: ('(b)', "sklearn usa convencao 'maior e melhor'. Para metricas de erro, o nome comeca com 'neg_' e o valor e negativo. Para recuperar o MSE real: -score.mean()."),
    76: ('(b)', 'Gap de 12pp entre treino e teste = overfitting. Solucoes: mais regularizacao, early stopping, menos features, mais dados.'),
    77: ('(b)', 'AUC-ROC pode ser otimista em dados muito desbalanceados. AUC-PR foca na classe minoritaria, sendo mais discriminativo quando positivos sao raros.'),
    78: ('(b)', 'KS e a distancia maxima entre as CDFs das duas classes. Quanto maior, melhor a separacao. Muito usado em credito bancario. Relacionado ao Gini: Gini = 2*AUC - 1.'),
    79: ('(b)', 'Pipeline garante que para cada fold de CV, o scaler e fitado APENAS no treino daquele fold. Sem isso, leakage indireto das estatisticas.'),
    80: ('(b)', 'Formula exata: Gini = 2 * AUC - 1. AUC=0.5 => Gini=0 (sem poder). AUC=1.0 => Gini=1 (perfeito). Muito usado em credit scoring.'),
    81: ('(a)', 'K-means alterna: (1) atribuir pontos ao centroide mais proximo, (2) recalcular centroides como media dos pontos atribuidos. Iterativamente.'),
    82: ('(d)', "Todos os tres sao metodos padrao. Elbow: procura 'cotovelo' no grafico de WCSS vs K. Silhueta: mede separacao e coesao. Gap: compara com distribuicao uniforme."),
    83: ('(b)', "Single Linkage = 'vizinho mais proximo'. Distancia entre clusters = menor distancia entre pontos dos dois clusters. Tende a formar clusters longos/encadeados. ESSA E A LOGICA DA Q30 DA PROVA DE 2019."),
    84: ('(b)', "Complete Linkage = 'vizinho mais distante'. Tende a formar clusters compactos e esfericos."),
    85: ('(c)', "PEGADINHA CLASSICA: muitos confundem Average com 'distancia entre centroides'. NAO. Average = media de TODAS as distancias par a par. 'Centroid Linkage' e outro metodo."),
    86: ('(b)', 'DBSCAN = Density-Based Spatial Clustering. Define clusters como regioes densas conectadas, separadas por regioes esparsas. Marca outliers como ruido.'),
    87: ('(a)', "Variancia explicada por PCk e autovalor_k / sum(todos_autovalores). Cumulativa: soma dos K primeiros / total. Exibida no 'scree plot'."),
    88: ('(a)', "K-means: (1) precisa de K, (2) assume clusters 'esfericos' (distancia euclidiana), (3) sensivel a escalas, (4) afetado por outliers. Para clusters nao-esfericos: DBSCAN ou GMM."),
    89: ('(b)', 'GMM: cada ponto pode pertencer a varios clusters com probabilidade (soft clustering). K-means e hard (cada ponto -> 1 cluster). GMM ainda requer K.'),
    90: ('(b)', 'Dendrograma = arvore de clustering. Voce corta horizontalmente para obter qualquer numero de clusters. A altura do corte e o limiar de distancia.'),
    91: ('(b)', 'INNER: so matches. LEFT: todos da esquerda + matches da direita (NULL onde nao ha). RIGHT: inverso. FULL OUTER: todos dos dois lados.'),
    92: ('(b)', '(a) retorna a TRANSACAO maior, nao o CNPJ com maior soma. (b) agrega com SUM por CNPJ e ordena. (d) so da a transacao maxima por cnpj.'),
    93: ('(b)', 'groupby + agg: agrupa por col e aplica funcao em valor. Equivalente a SELECT col, AVG(valor) GROUP BY col em SQL.'),
    94: ('(b)', 'isnull() retorna DataFrame de booleans (True onde NaN). sum() soma por coluna. Resultado: Serie com numero de NaN em cada coluna.'),
    95: ('(b)', 'DataFrame: estruturado, com schema, otimizado automaticamente. RDD: API mais antiga, baixo nivel, sem otimizacao. Prefira DataFrame em 99% dos casos.'),
    96: ('(a)', 'Dicts em Python usam hash tables -> O(1) medio para lookup, insert e delete. Pior caso O(n) em colisoes extremas (raro).'),
    97: ('(b)', "Point-in-time correctness = JAMAIS usar features 'do futuro' em relacao ao evento. Fundamental em feature stores para evitar leakage temporal em producao."),
    98: ('(b)', 'Athena: SQL serverless em dados no S3 (parquet, csv, json). Cobra por dado escaneado. Sempre use filtros de data para economia.'),
    99: ('(a)', 'Endpoint: hospedado 24/7, decisoes em milissegundos (ex: fraude Pix). Batch: inicia job, scoreia N observacoes, termina. Muito mais barato para volumes grandes sem urgencia.'),
    100: ('(b)', 'Pipeline padrao: (1) ingestao de dados, (2) engenharia de features (Feature Store), (3) treino do modelo, (4) deploy (endpoint ou batch), (5) monitoring (PSI, AUC, drift). Sempre nessa ordem.'),
}

# CORRECAO AUTOMATICA
certas = 0
erradas = 0
brancas = 0
erradas_detalhes = []

blocos_info = [
    (1, 20, 'Bloco 1 -- Estatistica'),
    (21, 40, 'Bloco 2 -- ML Conceitual'),
    (41, 55, 'Bloco 3 -- Regressao'),
    (56, 70, 'Bloco 4 -- Classificacao'),
    (71, 80, 'Bloco 5 -- Validacao/Metricas'),
    (81, 90, 'Bloco 6 -- Clustering/PCA'),
    (91, 100, 'Bloco 7 -- SQL/Python'),
]

bloco_stats = {nome: [0, 0, 0] for _, _, nome in blocos_info}

for num, resposta in minhas_respostas.items():
    correta, explicacao = gabarito[num]
    # Identificar bloco
    for ini, fim, nome in blocos_info:
        if ini <= num <= fim:
            break

    if resposta is None:
        brancas += 1
        bloco_stats[nome][2] += 1
    elif resposta.strip().lower() == correta.strip().lower():
        certas += 1
        bloco_stats[nome][0] += 1
    else:
        erradas += 1
        bloco_stats[nome][1] += 1
        erradas_detalhes.append((num, resposta, correta, explicacao))

# Pontuacao com sistema de penalidade
pontuacao_bruta = certas - erradas
pontuacao_bruta = max(0, pontuacao_bruta)

print('='*70)
print(' '*25 + 'RESULTADO DO SIMULADO')
print('='*70)
print()
print(f'  Certas:  {certas:>3}')
print(f'  Erradas: {erradas:>3}')
print(f'  Brancas: {brancas:>3}')
print(f'  {"-"*20}')
print(f'  Pontuacao (certas - erradas): {pontuacao_bruta}')
print()

print('='*70)
print('PERFORMANCE POR BLOCO')
print('='*70)
print()
print(f'{"Bloco":<35} {"Certas":>7} {"Erradas":>8} {"Brancas":>8}')
print('-'*70)
for _, _, nome in blocos_info:
    c, e, b = bloco_stats[nome]
    print(f'{nome:<35} {c:>7} {e:>8} {b:>8}')
print()

# DIAGNOSTICO
print('='*70)
print('DIAGNOSTICO')
print('='*70)
print()
if pontuacao_bruta >= 80:
    print(f'  NIVEL SENIOR -- Pontuacao {pontuacao_bruta} >= 80')
    print('  Voce passa na prova com folga. Impressionaria os avaliadores.')
    print('  Agora foque na entrevista tecnica e na apresentacao de projetos.')
elif pontuacao_bruta >= 60:
    print(f'  APROVACAO PROVAVEL -- Pontuacao {pontuacao_bruta}')
    print('  Voce deve passar. Revise os blocos com mais erradas:')
    for _, _, nome in blocos_info:
        c, e, b = bloco_stats[nome]
        if e >= 3:
            print(f'    - {nome}: {e} erradas')
elif pontuacao_bruta >= 40:
    print(f'  ZONA DE RISCO -- Pontuacao {pontuacao_bruta}')
    print('  Precisa de mais estudo. Seus pontos fracos:')
    for _, _, nome in blocos_info:
        c, e, b = bloco_stats[nome]
        if e >= c:
            print(f'    - {nome}: {e} erradas vs {c} certas -- REVISAR')
else:
    print(f'  BASE INSUFICIENTE -- Pontuacao {pontuacao_bruta}')
    print('  Volte aos guias 1-3 antes de refazer o simulado.')

print()

# DETALHES DAS ERRADAS COM EXPLICACAO
if erradas_detalhes:
    print('='*70)
    print('QUESTOES ERRADAS -- EXPLICACOES')
    print('='*70)
    print()
    for num, sua, correta, expl in erradas_detalhes:
        print(f'  Q{num:03d}: sua resposta = {sua} | correta = {correta}')
        print(f'        {expl}')
        print()

# %% [markdown]
# ---
# ## Apendice -- Gabarito Puro (somente letras)
#
# Lista das respostas corretas para consulta rapida. Use para conferir quando quiser.

# %%
print('='*60)
print('GABARITO PURO')
print('='*60)
print()
print('BLOCO 1 -- ESTATISTICA')
print('  Q001:(b)  Q002:(c)  Q003:(b)  Q004:(b)  Q005:(b)')
print('  Q006:(b)  Q007:(b)  Q008:(c)  Q009:(c)  Q010:(c)')
print('  Q011:(c)  Q012:(b)  Q013:(c)  Q014:(b)  Q015:(a)')
print('  Q016:(d)  Q017:(b)  Q018:(b)  Q019:(d)  Q020:(b)')
print()
print('BLOCO 2 -- ML CONCEITUAL')
print('  Q021:(b)  Q022:(b)  Q023:(c)  Q024:(d)  Q025:(b)')
print('  Q026:(a)  Q027:(b)  Q028:(b)  Q029:(b)  Q030:(b)')
print('  Q031:(c)  Q032:(d)  Q033:(c)  Q034:(b)  Q035:(c)')
print('  Q036:(b)  Q037:(b)  Q038:(c)  Q039:(c)  Q040:(c)')
print()
print('BLOCO 3 -- REGRESSAO')
print('  Q041:(b)  Q042:(b)  Q043:(b)  Q044:(a)  Q045:(d)')
print('  Q046:(b)  Q047:(a)  Q048:(b)  Q049:(c)  Q050:(b)')
print('  Q051:(b)  Q052:(a)  Q053:(b)  Q054:(c)  Q055:(b)')
print()
print('BLOCO 4 -- CLASSIFICACAO')
print('  Q056:(b)  Q057:(b)  Q058:(c)  Q059:(c)  Q060:(a)')
print('  Q061:(b)  Q062:(b)  Q063:(b)  Q064:(a)  Q065:(b)')
print('  Q066:(c)  Q067:(a)  Q068:(b)  Q069:(c)  Q070:(b)')
print()
print('BLOCO 5 -- VALIDACAO E METRICAS')
print('  Q071:(b)  Q072:(a)  Q073:(c)  Q074:(b)  Q075:(b)')
print('  Q076:(b)  Q077:(b)  Q078:(b)  Q079:(b)  Q080:(b)')
print()
print('BLOCO 6 -- CLUSTERING, PCA')
print('  Q081:(a)  Q082:(d)  Q083:(b)  Q084:(b)  Q085:(c)')
print('  Q086:(b)  Q087:(a)  Q088:(a)  Q089:(b)  Q090:(b)')
print()
print('BLOCO 7 -- SQL, PYTHON')
print('  Q091:(b)  Q092:(b)  Q093:(b)  Q094:(b)  Q095:(b)')
print('  Q096:(a)  Q097:(b)  Q098:(b)  Q099:(a)  Q100:(b)')
print()

# %% [markdown]
# ---
# ## Apendice -- Tabela de Referencia Rapida
#
# Se voce errou determinada questao, esta tabela aponta qual topico estudar.
#
# | Questoes | Topico | Guia recomendado |
# |----------|--------|------------------|
# | Q1-Q20 | Estatistica basica e inferencial | Parte 1 (Modulos 1-2) |
# | Q21-Q40 | ML Conceitual (algoritmos) | Parte 1 (Modulos 3-4) + Parte 2 + Parte 3 |
# | Q41-Q55 | Regressao e Regularizacao | Parte 1 (Modulo 3) + Parte 2 (Modulo 6) |
# | Q56-Q70 | Classificacao | Parte 1 (Modulo 4) + Parte 2 (Modulo 8) |
# | Q71-Q80 | Validacao e Metricas | Parte 2 (Modulo 5) + Guia Avancado (Topicos 1, 7) |
# | Q81-Q90 | Clustering, PCA | Parte 3 (Modulo 11) |
# | Q91-Q100 | SQL, Python, AWS | Parte 4 (Modulo C) + Pratica Guiada (Cap 5) |
#
# ---
#
# ## Apos completar o simulado
#
# **Se pontuou >= 80:**
# Parabens. Voce esta no nivel de senior.
# Foque agora em:
# 1. Apresentacao dos 3 projetos (Parte 5) em formato STAR
# 2. Preparacao para sabatina tecnica
# 3. Guia Avancado para aprofundamento
#
# **Se pontuou 60-79:**
# Voce passa na prova. Mas pode impressionar mais.
# 1. Revise blocos com mais erros
# 2. Refaca o simulado em 1 semana
# 3. Estude Guia Avancado topicos onde errou mais
#
# **Se pontuou < 60:**
# Ainda nao esta pronto. Planejamento:
# 1. Identifique o bloco mais fraco
# 2. Estude o guia correspondente (ver tabela acima)
# 3. Refaca apenas as questoes do bloco fraco
# 4. Quando as erradas caem a zero: refaz o simulado completo
#
# ---
#
# ## Como se preparar para a sabatina tecnica (pos-prova)
#
# A pesquisa no Glassdoor revelou as perguntas mais comuns:
#
# **Obrigatorio saber explicar com profundidade:**
# 1. L1 vs L2 (matematica, efeito nos coeficientes)
# 2. Arvore de decisao: criterio de split, quando parar
# 3. Random Forest, Bagging, Boosting -- diferencas
# 4. Clustering hierarquico: single, complete, average linkage
# 5. DBSCAN: funcionamento, eps, min_samples
# 6. Metricas de classificacao: quando cada uma falha
# 7. Metricas de regressao: diferenca RMSE vs MAE vs MAPE
# 8. SVM: margem, kernel trick, C e gamma
# 9. Naive Bayes: premissa, Gaussian vs Bernoulli
# 10. KNN: trade-off de K, escala das features
#
# **Voce vai receber um problema na hora. O entrevistador quer ver:**
# - Voce faz perguntas de clarificacao? (problema aberto)
# - Voce considera trade-offs? (velocidade vs precisao, interpretabilidade)
# - Voce pensa em producao? (monitoring, retreino, custo computacional)
# - Voce comunica resultado em linguagem de negocio?
#
# Boa prova!
